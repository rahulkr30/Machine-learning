# %%
import numpy as np
data = np.random.randn(100, 4)


cov_matrix = np.cov(data, rowvar=False)


eigenvalues, eigenvectors = np.linalg.eig(cov_matrix)

sorted_indices = np.argsort(eigenvalues)[::-1]
sorted_eigenvalues = eigenvalues[sorted_indices]
sorted_eigenvectors = eigenvectors[:, sorted_indices]

print("Sorted Eigenvalues:")
print(sorted_eigenvalues)
print("\nSorted Eigenvectors:")
print(sorted_eigenvectors)


# now selecting 2 coloumns 
main_vector=sorted_eigenvectors[:2]
# Out:
# Sorted Eigenvalues:
# [1.45495268 1.19382483 1.03354145 0.79936167]
#
# Sorted Eigenvectors:
# [[ 0.26976258  0.49089794  0.63273654  0.53468853]
#  [ 0.7670108  -0.05439382 -0.55418431  0.31877187]
#  [-0.53643183  0.47593414 -0.52646262  0.45668884]
#  [-0.22619346 -0.72769995  0.12394083  0.63555328]]

# %%
main_vector=sorted_eigenvectors[:,:2]

# %%
data_centered = data - np.mean(data, axis=0)

# %%
np.dot(data_centered,main_vector)
# Out:
# array([[ 0.10234999, -0.49175255],
#        [ 1.20204506,  1.50540628],
#        [-1.03106694,  1.00761708],
#        [ 0.3877169 , -0.87538437],
#        [ 0.62529423,  0.13952284],
#        [-0.83828678, -1.47353773],
#        [ 1.1858643 , -0.16659509],
#        [ 0.83725484, -0.88100863],
#        [-1.44136669,  0.74145673],
#        [-0.37138637, -0.68011298],
#        [-0.13085872,  0.46669273],
#        [-1.18085786, -1.29954551],
#        [ 0.27177461, -0.785641  ],
#        [ 1.43968081,  0.96125243],
#        [-0.98463328,  1.97036379],
#        [ 0.48394373, -0.68984472],
#        [ 0.6393164 ,  0.17032484],
#        [-0.02657802, -2.56671126],
#        [ 0.17147846, -1.06926249],
#        [ 0.75743617,  0.29751588],
#        [ 0.4626046 ,  0.38578241],
#        [-0.54568334, -0.03868716],
#        [ 0.06230324,  1.95484114],
#        [ 0.38790953, -1.11772955],
#        [-0.56706158, -0.40509273],
#        [-0.50639796, -0.43722825],
#        [ 1.01152963, -0.15905848],
#        [-1.3274475 , -1.30445294],
#        [ 0.30527198, -0.03935696],
#        [ 2.03865936, -0.67445659],
#        [-0.47177776,  1.92637323],
#        [ 1.25895719, -1.14457366],
#        [ 0.52674703,  0.88106117],
#        [ 0.48527241,  1.2695864 ],
#        [ 1.27257006, -1.51112857],
#        [-0.22536727,  1.77994261],
#        [-1.72078116, -0.08059585],
#        [ 2.47317626,  0.56017173],
#        [ 0.7760688 , -1.04870418],
#        [ 0.94316338, -0.70799907],
#        [-2.21280216,  1.31218072],
#        [-1.62160024,  0.08023763],
#        [ 2.82205748,  2.30098103],
#        [-0.40257801, -0.07569012],
#        [ 1.45224978,  0.47427807],
#        [-2.63015255, -0.74591582],
#        [-0.96745788,  1.63694382],
#        [-0.07898116, -1.20205477],
#        [-0.62292581,  0.84822567],
#        [ 2.03717211,  1.02638569],
#        [-0.65353236,  1.27142998],
#        [-0.35585939, -1.49184334],
#        [-0.7102143 , -0.78572072],
#        [-0.59506817, -0.76874214],
#        [-0.76065113, -0.10347086],
#        [-0.04245023, -0.06993318],
#        [ 0.04532911, -0.36855652],
#        [ 1.82360669, -0.30561696],
#        [-0.10374477, -0.99988077],
#        [ 1.55209099,  1.15424486],
#        [ 0.59657208,  1.4436515 ],
#        [ 0.2702298 ,  1.80904848],
#        [-1.72631308,  0.77563924],
#        [ 0.31300875, -0.21285625],
#        [-3.00754769,  1.03359157],
#        [ 0.45931241,  0.09215728],
#        [-0.82118304,  1.36267205],
#        [-2.65647925, -0.03253347],
#        [-0.33318824, -2.67103775],
#        [ 2.6204948 ,  1.08413268],
#        [ 0.70699102, -0.39539551],
#        [ 1.1087151 ,  0.60527942],
#        [-3.00365726,  1.92832568],
#        [-0.00626763,  0.2208228 ],
#        [ 1.11533656, -0.80581048],
#        [-0.62805436, -0.05512581],
#        [-0.93931172,  0.36936683],
#        [ 0.49222806, -0.89743402],
#        [-1.21640354,  1.12909943],
#        [ 0.01784339, -0.46921885],
#        [ 2.62389443,  0.34313187],
#        [-0.75608117,  0.16747131],
#        [-0.52710521,  1.41682813],
#        [ 0.87994559, -1.51284796],
#        [-0.84893616, -2.66802664],
#        [-0.92531828,  0.85741688],
#        [ 0.50849692, -1.43425325],
#        [ 0.18219151, -0.09886578],
#        [ 1.13716264, -0.64805972],
#        [ 1.13886664,  1.35342554],
#        [-0.04791252, -0.85374661],
#        [-0.44957952,  0.90370818],
#        [-0.82526268,  0.70938192],
#        [ 1.15941813, -1.22694588],
#        [-1.60124783, -0.42591125],
#        [-0.66184812,  0.3530747 ],
#        [-2.2501344 , -2.21740706],
#        [ 1.865988  , -0.26633449],
#        [-0.31044046, -0.11559521],
#        [-0.36774943, -0.50775271]])

# %%
from sklearn.decomposition import PCA

# %%
pca=PCA(n_components=2)

# %%
pca.fit_transform(data)
# Out:
# array([[-0.10234999,  0.49175255],
#        [-1.20204506, -1.50540628],
#        [ 1.03106694, -1.00761708],
#        [-0.3877169 ,  0.87538437],
#        [-0.62529423, -0.13952284],
#        [ 0.83828678,  1.47353773],
#        [-1.1858643 ,  0.16659509],
#        [-0.83725484,  0.88100863],
#        [ 1.44136669, -0.74145673],
#        [ 0.37138637,  0.68011298],
#        [ 0.13085872, -0.46669273],
#        [ 1.18085786,  1.29954551],
#        [-0.27177461,  0.785641  ],
#        [-1.43968081, -0.96125243],
#        [ 0.98463328, -1.97036379],
#        [-0.48394373,  0.68984472],
#        [-0.6393164 , -0.17032484],
#        [ 0.02657802,  2.56671126],
#        [-0.17147846,  1.06926249],
#        [-0.75743617, -0.29751588],
#        [-0.4626046 , -0.38578241],
#        [ 0.54568334,  0.03868716],
#        [-0.06230324, -1.95484114],
#        [-0.38790953,  1.11772955],
#        [ 0.56706158,  0.40509273],
#        [ 0.50639796,  0.43722825],
#        [-1.01152963,  0.15905848],
#        [ 1.3274475 ,  1.30445294],
#        [-0.30527198,  0.03935696],
#        [-2.03865936,  0.67445659],
#        [ 0.47177776, -1.92637323],
#        [-1.25895719,  1.14457366],
#        [-0.52674703, -0.88106117],
#        [-0.48527241, -1.2695864 ],
#        [-1.27257006,  1.51112857],
#        [ 0.22536727, -1.77994261],
#        [ 1.72078116,  0.08059585],
#        [-2.47317626, -0.56017173],
#        [-0.7760688 ,  1.04870418],
#        [-0.94316338,  0.70799907],
#        [ 2.21280216, -1.31218072],
#        [ 1.62160024, -0.08023763],
#        [-2.82205748, -2.30098103],
#        [ 0.40257801,  0.07569012],
#        [-1.45224978, -0.47427807],
#        [ 2.63015255,  0.74591582],
#        [ 0.96745788, -1.63694382],
#        [ 0.07898116,  1.20205477],
#        [ 0.62292581, -0.84822567],
#        [-2.03717211, -1.02638569],
#        [ 0.65353236, -1.27142998],
#        [ 0.35585939,  1.49184334],
#        [ 0.7102143 ,  0.78572072],
#        [ 0.59506817,  0.76874214],
#        [ 0.76065113,  0.10347086],
#        [ 0.04245023,  0.06993318],
#        [-0.04532911,  0.36855652],
#        [-1.82360669,  0.30561696],
#        [ 0.10374477,  0.99988077],
#        [-1.55209099, -1.15424486],
#        [-0.59657208, -1.4436515 ],
#        [-0.2702298 , -1.80904848],
#        [ 1.72631308, -0.77563924],
#        [-0.31300875,  0.21285625],
#        [ 3.00754769, -1.03359157],
#        [-0.45931241, -0.09215728],
#        [ 0.82118304, -1.36267205],
#        [ 2.65647925,  0.03253347],
#        [ 0.33318824,  2.67103775],
#        [-2.6204948 , -1.08413268],
#        [-0.70699102,  0.39539551],
#        [-1.1087151 , -0.60527942],
#        [ 3.00365726, -1.92832568],
#        [ 0.00626763, -0.2208228 ],
#        [-1.11533656,  0.80581048],
#        [ 0.62805436,  0.05512581],
#        [ 0.93931172, -0.36936683],
#        [-0.49222806,  0.89743402],
#        [ 1.21640354, -1.12909943],
#        [-0.01784339,  0.46921885],
#        [-2.62389443, -0.34313187],
#        [ 0.75608117, -0.16747131],
#        [ 0.52710521, -1.41682813],
#        [-0.87994559,  1.51284796],
#        [ 0.84893616,  2.66802664],
#        [ 0.92531828, -0.85741688],
#        [-0.50849692,  1.43425325],
#        [-0.18219151,  0.09886578],
#        [-1.13716264,  0.64805972],
#        [-1.13886664, -1.35342554],
#        [ 0.04791252,  0.85374661],
#        [ 0.44957952, -0.90370818],
#        [ 0.82526268, -0.70938192],
#        [-1.15941813,  1.22694588],
#        [ 1.60124783,  0.42591125],
#        [ 0.66184812, -0.3530747 ],
#        [ 2.2501344 ,  2.21740706],
#        [-1.865988  ,  0.26633449],
#        [ 0.31044046,  0.11559521],
#        [ 0.36774943,  0.50775271]])

# %%
pca.components_
# Out:
# array([[-0.26976258, -0.7670108 ,  0.53643183,  0.22619346],
#        [-0.49089794,  0.05439382, -0.47593414,  0.72769995]])

# %%
sorted_eigenvectors[:,:2]
# Out:
# array([[ 0.26976258,  0.49089794],
#        [ 0.7670108 , -0.05439382],
#        [-0.53643183,  0.47593414],
#        [-0.22619346, -0.72769995]])

# %%
#Svd

u,singular,v_t=np.linalg.svd(data)

# %%
eigenvalues.argsort()[::-1]
# Out:
# array([0, 1, 2, 3], dtype=int64)

# %%
# Out:
# array([[ 0.26976258,  0.53468853,  0.49089794,  0.63273654],
#        [ 0.7670108 ,  0.31877187, -0.05439382, -0.55418431],
#        [-0.53643183,  0.45668884,  0.47593414, -0.52646262],
#        [-0.22619346,  0.63555328, -0.72769995,  0.12394083]])

# %%
pca.components_
# Out:
# array([[-0.26976258, -0.7670108 ,  0.53643183,  0.22619346],
#        [-0.49089794,  0.05439382, -0.47593414,  0.72769995]])

# %%
pca.explained_variance_
# Out:
# array([1.45495268, 1.19382483])

# %%
v_t.T[:,:2]
# Out:
# array([[-0.26247976, -0.49421866],
#        [-0.7662366 ,  0.04066297],
#        [ 0.54499068, -0.47098497],
#        [ 0.21672793,  0.72956672]])

# %%
np.dot(data,v_t.T[:,:2])
# Out:
# array([[-0.04163097,  0.43500821],
#        [-1.113033  , -1.57424011],
#        [ 1.1136009 , -1.04731124],
#        [-0.33190413,  0.81432035],
#        [-0.55545344, -0.2025714 ],
#        [ 0.88338944,  1.43426042],
#        [-1.11856799,  0.09455797],
#        [-0.77529328,  0.80328104],
#        [ 1.52342663, -0.78176565],
#        [ 0.43377382,  0.62406221],
#        [ 0.20459309, -0.51672681],
#        [ 1.22975912,  1.26332526],
#        [-0.21311529,  0.72373942],
#        [-1.35271494, -1.0441116 ],
#        [ 1.08227978, -2.01042877],
#        [-0.42457343,  0.62665528],
#        [-0.57234684, -0.22776228],
#        [ 0.05867537,  2.51133488],
#        [-0.1168889 ,  1.01015135],
#        [-0.68491955, -0.36278213],
#        [-0.38902467, -0.44706906],
#        [ 0.61228203, -0.00693665],
#        [ 0.03419732, -2.01136957],
#        [-0.33814971,  1.0621552 ],
#        [ 0.62801201,  0.36036152],
#        [ 0.56863151,  0.38916588],
#        [-0.94695176,  0.09211809],
#        [ 1.37465366,  1.27318865],
#        [-0.23758896, -0.01875575],
#        [-1.97586853,  0.58425109],
#        [ 0.56429114, -1.96724107],
#        [-1.20543249,  1.06633089],
#        [-0.45095736, -0.93351531],
#        [-0.39388848, -1.33823682],
#        [-1.22640992,  1.44128616],
#        [ 0.32216042, -1.83544344],
#        [ 1.78741651,  0.0532763 ],
#        [-2.39334494, -0.65580305],
#        [-0.72159934,  0.98071648],
#        [-0.88379102,  0.63732482],
#        [ 2.29825511, -1.33002465],
#        [ 1.69003326, -0.1090465 ],
#        [-2.71910281, -2.39723517],
#        [ 0.4664888 ,  0.03163409],
#        [-1.37992881, -0.54535508],
#        [ 2.68710738,  0.72910658],
#        [ 1.0632108 , -1.68428919],
#        [ 0.12974442,  1.1481332 ],
#        [ 0.70496324, -0.8971348 ],
#        [-1.95641953, -1.10602497],
#        [ 0.7396855 , -1.31480009],
#        [ 0.40097107,  1.44413645],
#        [ 0.76752023,  0.74125838],
#        [ 0.64725858,  0.73107716],
#        [ 0.82524056,  0.06271349],
#        [ 0.10755377,  0.01966022],
#        [ 0.02103184,  0.30794475],
#        [-1.76206891,  0.22705163],
#        [ 0.15592409,  0.94934794],
#        [-1.46734752, -1.23004375],
#        [-0.51062668, -1.50122846],
#        [-0.172337  , -1.87224304],
#        [ 1.80666643, -0.80666169],
#        [-0.24642237,  0.15006346],
#        [ 3.08866634, -1.04216667],
#        [-0.38345092, -0.16303965],
#        [ 0.91094009, -1.40972456],
#        [ 2.72455022,  0.01542547],
#        [ 0.36333103,  2.6205064 ],
#        [-2.53759888, -1.17437041],
#        [-0.64447958,  0.33016417],
#        [-1.03163492, -0.67581512],
#        [ 3.09943995, -1.93915388],
#        [ 0.07545164, -0.27321715],
#        [-1.05704239,  0.7319474 ],
#        [ 0.69798533,  0.00566237],
#        [ 1.01490232, -0.41333348],
#        [-0.43555238,  0.83283104],
#        [ 1.30188691, -1.16804908],
#        [ 0.04433303,  0.41331254],
#        [-2.55151298, -0.43425486],
#        [ 0.82778517, -0.21285666],
#        [ 0.61478751, -1.46099892],
#        [-0.82826818,  1.43753581],
#        [ 0.87934941,  2.62333872],
#        [ 1.00726386, -0.89946785],
#        [-0.46378499,  1.37751141],
#        [-0.11666898,  0.04299725],
#        [-1.0808838 ,  0.58103065],
#        [-1.054007  , -1.42000328],
#        [ 0.10381635,  0.79804021],
#        [ 0.53242894, -0.95276276],
#        [ 0.90892325, -0.76051887],
#        [-1.10838058,  1.15511574],
#        [ 1.66659414,  0.38791347],
#        [ 0.73704761, -0.40020539],
#        [ 2.28506063,  2.19742801],
#        [-1.80358163,  0.18921946],
#        [ 0.37465058,  0.06789571],
#        [ 0.4263247 ,  0.46259563]])

# %%
singular
# Out:
# array([12.02093563, 10.88550627, 10.11577538,  8.89797532])
